# %% [markdown]
# # Fundamentals of ImageJ
# This tutorial will educate you on the basic concepts and usage of the ImageJ API.

# %% [markdown]
# ## The ImageJ gateway

# %% [markdown]
# The first step when working with ImageJ is to get or create an *ImageJ gateway*. This gateway provides access to ImageJ operations and data structures.

# %%
#@ImageJ ij

// Behind a firewall? Configure your proxy settings here.
//System.setProperty("http.proxyHost","myproxy.domain")
//System.setProperty("http.proxyPort","8080")

"ImageJ is ready to go."
# Out:
# ImageJ is ready to go.

# %% [markdown]
# In SciJava notebooks, you can get a handle on the notebook's existing gateway by using the [`#@parameter` syntax](https://imagej.net/Script_Parameters) as illustrated above.
#
# If you are writing standalone code intended for use outside of ImageJ or Jupyter, you can instead create a new ImageJ gateway:
# ```groovy
# import net.imagej.ImageJ
# ij = new ImageJ()
# ```

# %% [markdown]
# ## Services

# %% [markdown]
# ImageJ's functionality is divided into *services*.  Each service provides some API methods for performing related tasks.
#
# The gateway provides easy access to this slew of services. Here are some example service calls:

# %%
// The plugin service manages the available plugins (see "Plugins" below).
pluginCount = ij.plugin().getIndex().size()
println("There are " + pluginCount + " plugins available.")

// The log service is used for logging messages.
ij.log().warn("Ignoring negative sigma value.")

// The status service is used to report the current status of operations.
// Within a notebook like this, the call does not do anything visible.
ij.status().showStatus("Processing data file 34 of 97...")

// The menu service organizes a menu hierarchy for modules (see "Modules" below).
menuItemCount = ij.menu().getMenu().size()
println("There are " + menuItemCount + " menu items total.")

// The platform service handles platform-specific functionality.
// E.g., it can open a URL in the default web browser for your system:
// ij.platform().open(new URL("https://imagej.net/"))
# Out:
# There are 1506 plugins available.
# [WARNING] Ignoring negative sigma value.
# There are 260 menu items total.
# No Outputs

# %% [markdown]
# ### Comparison with ImageJ 1.x
# <div style="float: left"><img src="http://imagej.net/_images/a/a8/Imagej1-icon.png" width="48"></div>
#
# [ImageJ 1.x](https://imagej.net/ImageJ1) has a similar concept with the `ij.ImageJ` class, which is created using `new ImageJ()` and cached statically as a singleton.  This allows the ImageJ instance to be recovered later by calling `IJ.getInstance()`, and simplifies the API in some ways.  However, the assumption that there will only ever be one ImageJ per JVM limits its flexibility, and the fact that `ij.ImageJ` extends `java.awt.Frame` makes ImageJ 1.x difficult to use [headless](https://imagej.net/Headless) or with user interfaces other than Java AWT. Furthermore, [ImageJ 1.x](https://imagej.net/ImageJ1) is not service-driven, which makes it less extensible; see the <a href="../3_-_Advanced_usage/1_-_Under_the_hood_-_SciJava.ipynb">Under the hood: SciJava</a> tutorial notebook for more information.

# %% [markdown]
# ### How to explore the API

# %% [markdown]
# One very easy way to explore the API is via an [Integrated Development Environment (IDE)](https://imagej.net/IDEs) such as [Eclipse](https://imagej.net/Eclipse) or [IntelliJ IDEA](https://imagej.net/IDEA). You can use the IDE's autocomplete feature to list all of the available methods of a particular object. E.g., in Eclipse, if you press <kbd>ctrl</kbd>+<kbd>space</kbd> after a period (`.`) character on an object, you will see a list of methods which are available:
#
# <p><img src="ide-autocomplete.png"></p>
#
# Unfortunately, here in this notebook software, the autocompletion logic is not (yet!) advanced enough to fully offer such a feature—there is only rudimentary method completion support by pressing <kbd>tab</kbd>. Hence, the `NotebookService` also includes a handy method for inspecting an object's methods. Here is an example which will show the vailable ethods of a List:

# %%
// Create some arbitrary List
myList = ["quick", "brown", "fox"]
ij.notebook().methods(myList)
# Out:
# <style>table.converted {color: #333; font-family: Helvetica, Arial, sans-serif; border-collapse: collapse; border-spacing: 0;}table.converted td, table.converted th {border: 1px solid #C9C7C7;}table.converted th, table.converted td.rowLabel {background: #626262; color: #FFFFFF; font-weight: bold; text-align: left;}table.converted td {text-align: left;}table.converted tr:nth-child(even) {background: #F3F3F3;}table.converted tr:nth-child(odd) {background: #FFFFFF;}table.converted tbody tr:hover {background: #BDF4B5;}table.converted td.rowLabel, table.converted th.rowLabel {display: none;}</style><table class ="converted"><thead><tr><th>name</th><th>arguments</th><th>returns</th></tr></thead><tbody><tr><td>add</td><td>java&#8203;.lang&#8203;.Object</td><td>boolean</td></tr><tr><td>add</td><td>int, java&#8203;.lang&#8203;.Object</td><td>void</td></tr><tr><td>addAll</td><td>java&#8203;.util&#8203;.Collection</td><td>boolean</td></tr><tr><td>addAll</td><td>int, java&#8203;.util&#8203;.Collection</td><td>boolean</td></tr><tr><td>clear</td><td>&lt;none&gt;</td><td>void</td></tr><tr><td>clone</td><td>&lt;none&gt;</td><td>java&#8203;.lang&#8203;.Object</td></tr><tr><td>contains</td><td>java&#8203;.lang&#8203;.Object</td><td>boolean</td></tr><tr><td>containsAll</td><td>java&#8203;.util&#8203;.Collection</td><td>boolean</td></tr><tr><td>ensureCapacity</td><td>int</td><td>void</td></tr><tr><td>equals</td><td>java&#8203;.lang&#8203;.Object</td><td>boolean</td></tr><tr><td>forEach</td><td>java&#8203;.util&#8203;.function&#8203;.Consumer</td><td>void</td></tr><tr><td>get</td><td>int</td><td>java&#8203;.lang&#8203;.Object</td></tr><tr><td>getClass</td><td>&lt;none&gt;</td><td>java&#8203;.lang&#8203;.Class</td></tr><tr><td>hashCode</td><td>&lt;none&gt;</td><td>int</td></tr><tr><td>indexOf</td><td>java&#8203;.lang&#8203;.Object</td><td>int</td></tr><tr><td>isEmpty</td><td>&lt;none&gt;</td><td>boolean</td></tr><tr><td>iterator</td><td>&lt;none&gt;</td><td>java&#8203;.util&#8203;.Iterator</td></tr><tr><td>lastIndexOf</td><td>java&#8203;.lang&#8203;.Object</td><td>int</td></tr><tr><td>listIterator</td><td>&lt;none&gt;</td><td>java&#8203;.util&#8203;.ListIterator</td></tr><tr><td>listIterator</td><td>int</td><td>java&#8203;.util&#8203;.ListIterator</td></tr><tr><td>notify</td><td>&lt;none&gt;</td><td>void</td></tr><tr><td>notifyAll</td><td>&lt;none&gt;</td><td>void</td></tr><tr><td>parallelStream</td><td>&lt;none&gt;</td><td>java&#8203;.util&#8203;.stream&#8203;.Stream</td></tr><tr><td>remove</td><td>int</td><td>java&#8203;.lang&#8203;.Object</td></tr><tr><td>remove</td><td>java&#8203;.lang&#8203;.Object</td><td>boolean</td></tr><tr><td>removeAll</td><td>java&#8203;.util&#8203;.Collection</td><td>boolean</td></tr><tr><td>removeIf</td><td>java&#8203;.util&#8203;.function&#8203;.Predicate</td><td>boolean</td></tr><tr><td>replaceAll</td><td>java&#8203;.util&#8203;.function&#8203;.UnaryOperator</td><td>void</td></tr><tr><td>retainAll</td><td>java&#8203;.util&#8203;.Collection</td><td>boolean</td></tr><tr><td>set</td><td>int, java&#8203;.lang&#8203;.Object</td><td>java&#8203;.lang&#8203;.Object</td></tr><tr><td>size</td><td>&lt;none&gt;</td><td>int</td></tr><tr><td>sort</td><td>java&#8203;.util&#8203;.Comparator</td><td>void</td></tr><tr><td>spliterator</td><td>&lt;none&gt;</td><td>java&#8203;.util&#8203;.Spliterator</td></tr><tr><td>stream</td><td>&lt;none&gt;</td><td>java&#8203;.util&#8203;.stream&#8203;.Stream</td></tr><tr><td>subList</td><td>int, int</td><td>java&#8203;.util&#8203;.List</td></tr><tr><td>toArray</td><td>&lt;none&gt;</td><td>[Ljava&#8203;.lang&#8203;.Object;</td></tr><tr><td>toArray</td><td>[Ljava&#8203;.lang&#8203;.Object;</td><td>[Ljava&#8203;.lang&#8203;.Object;</td></tr><tr><td>toString</td><td>&lt;none&gt;</td><td>java&#8203;.lang&#8203;.String</td></tr><tr><td>trimToSize</td><td>&lt;none&gt;</td><td>void</td></tr><tr><td>wait</td><td>&lt;none&gt;</td><td>void</td></tr><tr><td>wait</td><td>long</td><td>void</td></tr><tr><td>wait</ ...

# %% [markdown]
# Try it yourself on the ImageJ service of your choice!

# %% [markdown]
# ### Complete list of built-in services

# %% [markdown]
# Here is the complete list of built-in services accessible from the ImageJ gateway:

# %%
ij.notebook().methods(ij).findAll{ it.get("returns").endsWith("Service") }
# Out:
# <style>table.converted {color: #333; font-family: Helvetica, Arial, sans-serif; border-collapse: collapse; border-spacing: 0;}table.converted td, table.converted th {border: 1px solid #C9C7C7;}table.converted th, table.converted td.rowLabel {background: #626262; color: #FFFFFF; font-weight: bold; text-align: left;}table.converted td {text-align: left;}table.converted tr:nth-child(even) {background: #F3F3F3;}table.converted tr:nth-child(odd) {background: #FFFFFF;}table.converted tbody tr:hover {background: #BDF4B5;}table.converted td.rowLabel, table.converted th.rowLabel {display: none;}</style><table class ="converted"><thead><tr><th>name</th><th>arguments</th><th>returns</th></tr></thead><tbody><tr><td>animation</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.animation&#8203;.AnimationService</td></tr><tr><td>app</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.app&#8203;.AppService</td></tr><tr><td>appEvent</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.platform&#8203;.AppEventService</td></tr><tr><td>command</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.command&#8203;.CommandService</td></tr><tr><td>console</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.console&#8203;.ConsoleService</td></tr><tr><td>convert</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.convert&#8203;.ConvertService</td></tr><tr><td>dataset</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.DatasetService</td></tr><tr><td>display</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.display&#8203;.DisplayService</td></tr><tr><td>event</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.event&#8203;.EventService</td></tr><tr><td>get</td><td>java&#8203;.lang&#8203;.Class</td><td>org&#8203;.scijava&#8203;.service&#8203;.Service</td></tr><tr><td>get</td><td>java&#8203;.lang&#8203;.String</td><td>org&#8203;.scijava&#8203;.service&#8203;.Service</td></tr><tr><td>icon</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.tool&#8203;.IconService</td></tr><tr><td>imageDisplay</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.display&#8203;.ImageDisplayService</td></tr><tr><td>input</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.input&#8203;.InputService</td></tr><tr><td>io</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.io&#8203;.IOService</td></tr><tr><td>log</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.log&#8203;.LogService</td></tr><tr><td>lut</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.lut&#8203;.LUTService</td></tr><tr><td>main</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.main&#8203;.MainService</td></tr><tr><td>menu</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.menu&#8203;.MenuService</td></tr><tr><td>module</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.module&#8203;.ModuleService</td></tr><tr><td>notebook</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.notebook&#8203;.NotebookService</td></tr><tr><td>object</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.object&#8203;.ObjectService</td></tr><tr><td>op</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.ops&#8203;.OpService</td></tr><tr><td>options</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.options&#8203;.OptionsService</td></tr><tr><td>overlay</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.display&#8203;.OverlayService</td></tr><tr><td>platform</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.platform&#8203;.PlatformService</td></tr><tr><td>plugin</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.plugin&#8203;.PluginService</td></tr><tr><td>prefs</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.prefs&#8203;.PrefService</td></tr><tr><td>recentFile</td><td>&lt;none&gt;</td><td>org&#8203;.scijava&#8203;.io&#8203;.RecentFileService</td></tr><tr><td>rendering</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.render&#8203;.RenderingService</td></tr><tr><td>sampler</td><td>&lt;none&gt;</td><td>net&#8203;.imagej&#8203;.sampler&#8203;.SamplerServ ...

# %% [markdown]
# ## Plugins

# %% [markdown]
# ImageJ is built on the [SciJava plugin framework](http://imagej.net/SciJava_Common). Essentially everything in ImageJ is a [plugin](http://imagej.net/Plugins).
#
# There are many kinds of plugins, and you can also define your own new kinds. Some of the most central built-in plugin types are:
#
# * `Service` – A collection of related functionality. See "Services" above.
# * `Module` – A routine which can be executed. See "Modules" below.
# * `IOPlugin` – A plugin for reading and/or writing data to/from external locations. See "Data I/O" below.

# %% [markdown]
# ### Complete list of built-in plugin types

# %% [markdown]
# The `PluginService` provides access to meta-information about available plugins. Here is a count of plugins organized by kind:

# %%
// Gather a count of each kind of plugin.
kindCounts = [:]
ij.plugin().getPlugins().forEach{plugin ->
  kind = plugin.getPluginType().getName()
  // HACK: Report all Op plugin subtypes as simply "Op", to avoid overwhelming the list.
  if (kind.startsWith('net.imagej.ops.Ops') || kind.startsWith('net.imagej.ops.features'))
    kind = 'net.imagej.ops.Op'
  kindCounts.put(kind, kindCounts.getOrDefault(kind, 0) + 1)
}
// Build a table which reports this information nicely.
kindCounts.keySet().sort().stream().map{kind -> [
    "package": (kind =~ /^.*\./)[0][0..-2],
    "class": (kind =~ /\.[^\.]*$/)[0][1..-1],
    "count": kindCounts.get(kind)
]}.collect()
# Out:
# <style>table.converted {color: #333; font-family: Helvetica, Arial, sans-serif; border-collapse: collapse; border-spacing: 0;}table.converted td, table.converted th {border: 1px solid #C9C7C7;}table.converted th, table.converted td.rowLabel {background: #626262; color: #FFFFFF; font-weight: bold; text-align: left;}table.converted td {text-align: left;}table.converted tr:nth-child(even) {background: #F3F3F3;}table.converted tr:nth-child(odd) {background: #FFFFFF;}table.converted tbody tr:hover {background: #BDF4B5;}table.converted td.rowLabel, table.converted th.rowLabel {display: none;}</style><table class ="converted"><thead><tr><th>package</th><th>class</th><th>count</th></tr></thead><tbody><tr><td>io&#8203;.scif</td><td>Format</td><td>29</td></tr><tr><td>io&#8203;.scif</td><td>Translator</td><td>11</td></tr><tr><td>io&#8203;.scif&#8203;.codec</td><td>Codec</td><td>16</td></tr><tr><td>io&#8203;.scif&#8203;.filters</td><td>Filter</td><td>5</td></tr><tr><td>io&#8203;.scif&#8203;.filters</td><td>MetadataWrapper</td><td>1</td></tr><tr><td>io&#8203;.scif&#8203;.img&#8203;.converters</td><td>PlaneConverter</td><td>3</td></tr><tr><td>io&#8203;.scif&#8203;.io</td><td>IStreamAccess</td><td>4</td></tr><tr><td>io&#8203;.scif&#8203;.refs</td><td>RefProvider</td><td>5</td></tr><tr><td>net&#8203;.imagej&#8203;.autoscale</td><td>AutoscaleMethod</td><td>2</td></tr><tr><td>net&#8203;.imagej&#8203;.display</td><td>DataView</td><td>2</td></tr><tr><td>net&#8203;.imagej&#8203;.legacy&#8203;.plugin</td><td>LegacyEditor</td><td>1</td></tr><tr><td>net&#8203;.imagej&#8203;.legacy&#8203;.plugin</td><td>LegacyOpener</td><td>1</td></tr><tr><td>net&#8203;.imagej&#8203;.minmax</td><td>MinMaxMethod</td><td>1</td></tr><tr><td>net&#8203;.imagej&#8203;.operator</td><td>CalculatorOp</td><td>13</td></tr><tr><td>net&#8203;.imagej&#8203;.ops</td><td>Namespace</td><td>22</td></tr><tr><td>net&#8203;.imagej&#8203;.ops</td><td>Op</td><td>820</td></tr><tr><td>net&#8203;.imagej&#8203;.threshold</td><td>ThresholdMethod</td><td>17</td></tr><tr><td>net&#8203;.imagej&#8203;.types</td><td>DataType</td><td>11</td></tr><tr><td>net&#8203;.imagej&#8203;.ui&#8203;.swing&#8203;.overlay</td><td>JHotDrawAdapter</td><td>10</td></tr><tr><td>net&#8203;.imagej&#8203;.updater</td><td>UpdaterUI</td><td>1</td></tr><tr><td>net&#8203;.imagej&#8203;.updater</td><td>Uploader</td><td>4</td></tr><tr><td>org&#8203;.scijava</td><td>Gateway</td><td>3</td></tr><tr><td>org&#8203;.scijava&#8203;.app</td><td>App</td><td>5</td></tr><tr><td>org&#8203;.scijava&#8203;.command</td><td>Command</td><td>183</td></tr><tr><td>org&#8203;.scijava&#8203;.console</td><td>ConsoleArgument</td><td>17</td></tr><tr><td>org&#8203;.scijava&#8203;.convert</td><td>Converter</td><td>72</td></tr><tr><td>org&#8203;.scijava&#8203;.display</td><td>Display</td><td>4</td></tr><tr><td>org&#8203;.scijava&#8203;.io</td><td>DataHandle</td><td>1</td></tr><tr><td>org&#8203;.scijava&#8203;.io</td><td>IOPlugin</td><td>4</td></tr><tr><td>org&#8203;.scijava&#8203;.module&#8203;.process</td><td>PostprocessorPlugin</td><td>2</td></tr><tr><td>org&#8203;.scijava&#8203;.module&#8203;.process</td><td>PreprocessorPlugin</td><td>29</td></tr><tr><td>org&#8203;.scijava&#8203;.options</td><td>OptionsPlugin</td><td>20</td></tr><tr><td>org&#8203;.scijava&#8203;.platform</td><td>Platform</td><td>3</td></tr><tr><td>org&#8203;.scijava&#8203;.run</td><td>CodeRunner</td><td>5</td></tr><tr><td>org&#8203;.scijava&#8203;.script</td><td>ScriptHeader</td><td>1</td></tr><tr><td>org&#8203;.scijava&#8203;.script</td><td>ScriptLanguage</td><td>10</td></tr><tr><td>org&#8203;.scijava&#8203;.script&#8203;.process</td><td>ScriptProcessor</td><td>3</td></tr><tr><td>org&#8203;.scijava&#8203;.service</td><td>Service</td><td>93</td></tr><tr><td>org&#8203;.scijava&#8203;.text</td><td>TextFormat</td><td>2</td></tr><tr><td>org&#8203;.scijava&#8203;.tool</td><td>Tool</td><td>26</td></tr><tr><td>org&#8203;.scijava&#8203;.ui</td><td>UserInterface</td><td>5</td></tr><tr><td>org&#8 ...

# %% [markdown]
# ## Data I/O

# %% [markdown]
# The I/O service provides a generalized API for reading and writing from external sources.

# %% [markdown]
# ### Loading data

# %% [markdown]
# Here is an example invocation which opens an image from a remote URL:

# %%
snowflake = ij.io().open("http://imagej.net/images/snowflake.gif")
# Out:
# [INFO] Verifying GIF format
# [INFO] Reading dimensions
# [INFO] Reading data blocks

# %% [markdown]
# ### Saving data

# %% [markdown]
# Similarly, you can use the I/O service to save data to an external destination:

# %%
destPath = System.getProperty("user.home") + "/Desktop/snowflake.png"
ij.io().save(snowflake, destPath)
"Saved to '$destPath'; length = ${new File(destPath).length()}"
# Out:
# Saved to '/Users/curtis/Desktop/snowflake&#8203;.png'; length = 2965

# %% [markdown]
# ### Bio-Formats
#
# Out of the box, SciJava notebooks do not include the [Bio-Formats](https://imagej.net/Bio-Formats) plugin for reading and writing life sciences images. For the moment, you can enable it as described in [this gist](https://gist.github.com/ctrueden/c26b1eb592db2897ab1061031e726620). Future versions of the SciJava Jupyter Kernel will make it simpler to dynamically add such extensions.

# %% [markdown]
# ## Modules

# %% [markdown]
# A SciJava _module_ is an executable snippet of code with _typed inputs and outputs_. You can think of them as <a href="https://en.wikipedia.org/wiki/Subroutine">subroutines</a>, also called _functions_ or _methods_ depending on the programming language.
#
# There are two main flavors of module: _commands_ and _scripts_. A `Command` is a plugin written in Java, whereas a script is written in one of the many available [SciJava scripting languages](https://imagej.net/Scripting). Most users who need to code a module will use a script, because they are simpler to write.

# %% [markdown]
# ### Scripts

# %% [markdown]
# Here is a sample module, written as a script:
# ```python
# #@input String name
# #@output String greeting
# #@output int length
# greeting = "Hello, " + name + "!"
# length = name.length()
# ```
# You can write scripts such as the above e.g. into ImageJ's [Script Editor](https://imagej.net/Script_Editor), and then run them directly. You can also write them as cells in SciJava notebooks such as this one.
#
# ImageJ (or more precisely: the SciJava script framework) will harvest the input parameters—in this case, the `name` string—from the user in a way appropriate to the execution context. For example, when running from the ImageJ user interface, a [Swing](https://en.wikipedia.org/wiki/Swing_(Java) dialog box will appear asking the user to type in a name. But when running from the command line, the input values can be passed as arguments to the command line invocation; see the [Scripting Headless](http://imagej.net/Scripting_Headless) page for details. The module outputs—in this case, `greeting` and `length`—will then be displayed to the user in a manner appropriate to the situation: when running graphically, one or more windows will typically pop up; when running from the CLI, output values will be logged to the standard output stream.
#
# The [Script Parameters](http://imagej.net/Script_Parameters) page provides more information about using these parameters in your scripts.
#
# Now let's run this script here in the notebook, and see what happens:

# %%
// Write the script as a string constant, so it can be passed to the script service.
// NB: '\n' is used to avoid those lines being parsed as parameters by this cell itself.
script = """
\n#@input String name
\n#@output String greeting
\n#@output int length
greeting = "Hello, " + name + "!"
length = name.length()
"""

// Run the script, passing input key/value pairs using a map.
inputs = ["name": System.getProperty("user.name")]
module = ij.script().run("greeting.groovy", script, true, inputs).get();

// Extract the module output values.
["greeting" : module.getOutput("greeting"),
 "length"   : module.getOutput("length")]
# Out:
# <style>table.converted {color: #333; font-family: Helvetica, Arial, sans-serif; border-collapse: collapse; border-spacing: 0;}table.converted td, table.converted th {border: 1px solid #C9C7C7;}table.converted th, table.converted td.rowLabel {background: #626262; color: #FFFFFF; font-weight: bold; text-align: left;}table.converted td {text-align: left;}table.converted tr:nth-child(even) {background: #F3F3F3;}table.converted tr:nth-child(odd) {background: #FFFFFF;}table.converted tbody tr:hover {background: #BDF4B5;}table.converted td.rowLabel, table.converted th.rowLabel {display: none;}</style><table class ="converted"><thead><tr><th>Key</th><th>Value</th></tr></thead><tbody><tr><td>greeting</td><td>Hello, curtis!</td></tr><tr><td>length</td><td>6</td></tr></tbody></table>

# %% [markdown]
# ### Commands

# %% [markdown]
# Here is the same example module, but written as a command:

# %%
// NB: While this is a Groovy cell, the class definition here is valid Java.

import org.scijava.ItemIO;
import org.scijava.command.Command;
import org.scijava.plugin.Parameter;
import org.scijava.plugin.Plugin;

@Plugin(type = Command.class)
public class Hello implements Command {
  
  @Parameter
  private String name;
  
  @Parameter(type = ItemIO.OUTPUT)
  private String greeting;
  
  @Parameter(type = ItemIO.OUTPUT)
  private int length;
  
  @Override
  public void run() {
    greeting = "Hello, " + name + "!";
    length = name.length();
  }
}

// Save a reference to the class, for use in the next cell.
greetingCommand = Hello.class
# Out:
# class Hello

# %% [markdown]
# As you can see, commands are more verbose. But there are advantages to using Java, such as performance, reusability, type safety, and powerful IDE features like autocompletion.
#
# Let's run this command using the command service:

# %%
// Run the command, passing input key/value pairs using a map.
inputs = ["name": "John Jacob Jingleheimer Schmidt"]
module = ij.command().run(greetingCommand, true, inputs).get()

// Extract the module output values.
["greeting" : module.getOutput("greeting"),
 "length"   : module.getOutput("length")]
# Out:
# <style>table.converted {color: #333; font-family: Helvetica, Arial, sans-serif; border-collapse: collapse; border-spacing: 0;}table.converted td, table.converted th {border: 1px solid #C9C7C7;}table.converted th, table.converted td.rowLabel {background: #626262; color: #FFFFFF; font-weight: bold; text-align: left;}table.converted td {text-align: left;}table.converted tr:nth-child(even) {background: #F3F3F3;}table.converted tr:nth-child(odd) {background: #FFFFFF;}table.converted tbody tr:hover {background: #BDF4B5;}table.converted td.rowLabel, table.converted th.rowLabel {display: none;}</style><table class ="converted"><thead><tr><th>Key</th><th>Value</th></tr></thead><tbody><tr><td>greeting</td><td>Hello, John Jacob Jingleheimer Schmidt!</td></tr><tr><td>length</td><td>31</td></tr></tbody></table>

# %% [markdown]
# ### Complete list of built-in modules

# %% [markdown]
# The `ModuleService` provides access to meta-information about available modules. Here is a list of all modules built in to ImageJ:

# %%
modules = []
ij.module().getModules().stream().map{module -> [
  "id": module.getIdentifier(),
  "location": module.getLocation().replaceAll('.*/(.*\\.jar)$', '$1'),
  "version": module.getVersion()
]}.collect()
# Out:
# <style>table.converted {color: #333; font-family: Helvetica, Arial, sans-serif; border-collapse: collapse; border-spacing: 0;}table.converted td, table.converted th {border: 1px solid #C9C7C7;}table.converted th, table.converted td.rowLabel {background: #626262; color: #FFFFFF; font-weight: bold; text-align: left;}table.converted td {text-align: left;}table.converted tr:nth-child(even) {background: #F3F3F3;}table.converted tr:nth-child(odd) {background: #FFFFFF;}table.converted tbody tr:hover {background: #BDF4B5;}table.converted td.rowLabel, table.converted th.rowLabel {display: none;}</style><table class ="converted"><thead><tr><th>id</th><th>location</th><th>version</th></tr></thead><tbody><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultVerticesCountPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultVerticesCountConvexHullPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultConvexityPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultBoundarySizeConvexHullPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultBoxivityPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultSizeConvexHullPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom2d&#8203;.DefaultSolidityPolygon</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultBoxivityMesh</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultCompactness</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultVerticesCountConvexHullMesh</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultVolumeConvexHullMesh</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultConvexityMesh</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultMainElongation</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultMedianElongation</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultSolidityMesh</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultSparenessMesh</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.imagej&#8203;.ops&#8203;.geom&#8203;.geom3d&#8203;.DefaultSphericity</td><td>imagej-ops-0&#8203;.38&#8203;.0&#8203;.jar</td><td>0&#8203;.38&#8203;.0</td></tr><tr><td>command:net&#8203;.im ...

# %% [markdown]
# ### Further reading

# %% [markdown]
# For more information about how to write commands and scripts, see the "Extending ImageJ" tutorial notebooks.

# %% [markdown]
# ## Ops

# %% [markdown]
# The true meat of ImageJ is [ImageJ Ops](https://imagej.net/Ops), a library for reusable image processing. An `Op` plugin is a form of `Command`, and therefore a module.
#
# Please proceed to the "Introduction to ImageJ Ops" tutorial notebook for a primer with lots of examples!

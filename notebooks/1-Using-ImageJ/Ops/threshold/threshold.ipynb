// %% [markdown]
// # Thresholding

// %%
//load ImageJ
%classpath config resolver scijava.public https://maven.scijava.org/content/groups/public
%classpath add mvn net.imagej imagej 2.0.0-rc-71

//create ImageJ object
ij = new net.imagej.ImageJ()
// Out:
// Added new repo: scijava.public
// net.imagej.ImageJ@2f661ef8

// %% [markdown]
// There are many cases in which you might want a binary image. For example, let's say you want to binarize this image:

// %%
input = ij.scifio().datasetIO().open("http://imagej.net/images/lymp.tif")

ij.notebook().display(input)
// Out:
// <img src="data:image/png;charset=utf-8;base64,..." />

// %% [markdown]
// Fortunately for you, ImageJ-Ops features many different algorithms that can be used to do so. Let's take a look at them!

// %% [markdown]
// ## [Huang Thresholding](https://imagej.net/Auto_Threshold#Huang)

// %%
huang = ij.op().run("threshold.huang", input)

ij.notebook().display([["Original" : input, "Huang Thresholded": huang]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Huang Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## IJ1 Thresholding

// %%
ij1 = ij.op().run("threshold.ij1", input)

ij.notebook().display([["Original" : input, "IJ1 Thresholded": ij1]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>IJ1 Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Intermodes Thresholding](https://imagej.net/Auto_Threshold#Intermodes)

// %%
intermodes = ij.op().run("threshold.intermodes", input)

ij.notebook().display([["Original" : input, "Intermodes Thresholded": intermodes]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Intermodes Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [IsoData](https://imagej.net/Auto_Threshold#IsoData)

// %%
isoData = ij.op().run("threshold.isoData", input)

ij.notebook().display([["Original" : input, "Isodata Thresholded": isoData]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Isodata Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Li](https://imagej.net/Auto_Threshold#Li)

// %%
li = ij.op().run("threshold.li", input)

ij.notebook().display([["Original" : input, "Li Thresholded": li]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Li Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [MaxEntropy](https://imagej.net/Auto_Threshold#MaxEntropy)

// %%
maxEntropy = ij.op().run("threshold.maxEntropy", input)

ij.notebook().display([["Original" : input, "MaxEntropy Thresholded": maxEntropy]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>MaxEntropy Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Mean](https://imagej.net/Auto_Threshold#Mean)

// %%
mean = ij.op().run("threshold.mean", input)

ij.notebook().display([["Original" : input, "Mean Thresholded": mean]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Mean Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [MinError](https://imagej.net/Auto_Threshold#MinError.28I.29)

// %%
minError = ij.op().run("threshold.minError", input)

ij.notebook().display([["Original" : input, "MinError Thresholded": minError]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>MinError Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Minimum](https://imagej.net/Auto_Threshold#Minimum)

// %%
minimum = ij.op().run("threshold.minimum", input)

ij.notebook().display([["Original" : input, "Minimum Thresholded": minimum]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Minimum Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Moments](https://imagej.net/Auto_Threshold#Moments)

// %%
moments = ij.op().run("threshold.moments", input)

ij.notebook().display([["Original" : input, "Moments Thresholded": moments]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Moments Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Otsu](https://imagej.net/Auto_Threshold#Otsu)

// %%
otsu = ij.op().run("threshold.otsu", input)

ij.notebook().display([["Original" : input, "Otsu Thresholded": otsu]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Otsu Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Percentile](https://imagej.net/Auto_Threshold#Percentile)

// %%
percentile = ij.op().run("threshold.percentile", input)

ij.notebook().display([["Original" : input, "Percentile Thresholded": percentile]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Percentile Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [RenyiEntropy](https://imagej.net/Auto_Threshold#RenyiEntropy)

// %%
renyiEntropy = ij.op().run("threshold.renyiEntropy", input)

ij.notebook().display([["Original" : input, "RenyiEntropy Thresholded": renyiEntropy]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>RenyiEntropy Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Shanbhag](https://imagej.net/Auto_Threshold#Shanbhag)

// %%
shanbhag = ij.op().run("threshold.shanbhag", input)

ij.notebook().display([["Original" : input, "Shanbhag Thresholded": shanbhag]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Shanbhag Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Triangle](https://imagej.net/Auto_Threshold#Triangle)

// %%
triangle = ij.op().run("threshold.triangle", input)

ij.notebook().display([["Original" : input, "Triangle Thresholded": triangle]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Triangle Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

// %% [markdown]
// ## [Yen](https://imagej.net/Auto_Threshold#Yen)

// %%
yen = ij.op().run("threshold.yen", input)

ij.notebook().display([["Original" : input, "Yen Thresholded": yen]])
// Out:
// <table class ="scijava"><thead><tr><th>Original</th><th>Yen Thresholded</th></tr></thead><tbody><tr><td><img src="data:image/png;charset=utf-8;base64,..." /></td><td><img src="data:image/png;charset=utf-8;base64,..." /></td></tr></tbody></table>

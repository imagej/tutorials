// %% [markdown]
// ## Arithmetic Mean

// %%
//load ImageJ
%classpath config resolver scijava.public https://maven.scijava.org/content/groups/public
%classpath add mvn net.imagej imagej 2.0.0-rc-67

//create ImageJ object
ij = new net.imagej.ImageJ()
// Out:
// Added new repo: scijava.public
// net.imagej.ImageJ@6d87e0

// %% [markdown]
// This `Op` calculates the [Arithmetic Mean](https://en.wikipedia.org/wiki/Mean#Arithmetic_mean_(AM)) of any [`Iterable`](https://docs.oracle.com/javase/8/docs/api/java/lang/Iterable.html) via the [`sum`](sum.ipynb) and [`size`](size.ipynb) `Op`s.

// %%
sinusoid32 = ij.op().run("create.img", [150, 100])
formula = "63 * (Math.cos(0.3*p[0]) + Math.sin(0.3*p[1])) + 127"
ij.op().image().equation(sinusoid32, formula)

ij.notebook().display(sinusoid32)

// %% [markdown]
// All `Img`s are `Iterable`s, so we can just pass through the `Img` to `mean()`:

// %%
import net.imglib2.type.numeric.real.DoubleType

output = new DoubleType()

ij.op().stats().mean(output, sinusoid32)

output
// Out:
// 130.35596075261444
